# %% [markdown]
# # Project 2: Simple Expense Tracker Application
# Objective: This notebook demonstrates the full application by importing user-defined modules

# %%
import main_mod as mm
mm.main()
# Out:
# ---Expense Tracker---
# 1. Add Expense
# 2. View All
# 3. Total by Category
# 4. View Summary
# 5. Exit
# Select an option (1-5):  1
# Enter Date (YYYY-MM-DD):  2025-12-01
# Category:  Clothing
# Description:  mini skirt
# Amount: 200
# ---Expense Tracker---
# 1. Add Expense
# 2. View All
# 3. Total by Category
# 4. View Summary
# 5. Exit
# Select an option (1-5):  1
# Enter Date (YYYY-MM-DD):  2025-12-02
# Category:  Accessories
# Description:  sun glasses
# Amount: 150
# ---Expense Tracker---
# 1. Add Expense
# 2. View All
# 3. Total by Category
# 4. View Summary
# 5. Exit
# Select an option (1-5):  1
# Enter Date (YYYY-MM-DD):  2025-12-03
# Category:  clothing
# Description:  T-shirts
# Amount: 350
# ---Expense Tracker---
# 1. Add Expense
# 2. View All
# 3. Total by Category
# 4. View Summary
# 5. Exit
# Select an option (1-5):  1
# Enter Date (YYYY-MM-DD):  2025-12-11
# Category:  Footwear
# Description:  Sneakers
# Amount: 200
# ---Expense Tracker---
# 1. Add Expense
# ...
